# %% [markdown]
# # Description
# Find the actual component values of the coil and capacitor in the bandpass filter in the figure below.
#
# The following steps are required:
#
# 1. Compare the measured response voltage $U_a$ with the predicted response voltage under nominal component values.
# 2. Determine the root mean square error (rmse).
# 3. Create a function find the rsme for different values of $L$ and $C$.
# 4. Minimize the rmse function to find the actual component values.
#
# ![Circuit Diagramm](circuit.png)

# %%
from matplotlib import pyplot as plt
import numpy as np
# import pandas as pd
import scipy as sci

# %% [markdown]
# # Get Data

# %%
COIL_NOMINAL=9e-3
CAPACITOR_NOMINAL=1000e-6

def get_measured_data(filename: str) -> dict[str, list[float]]:    
    """
    Import measured data from file and return as a dictionary.

    Input: name of the file where the measured data is stored. File must be npz or npy encoded. Column names must be "t_mess" and "u_a_mess".
    Output: a DataFrame containing the measured data.
    """
    with np.load(filename) as file:
        return {"time" : file["t_mess"], "measured voltage" : file["u_a_mess"]}

def predict_voltage(coil: float, capacitor: float) -> list[float]:
    """
    Create a LTI System with a transfer function dependent on the resistors and return the output voltage of that system.

    Input: the values for the coil and capacitor in H and F.
    Output: A 1D list of the output voltage at time steps specified by the measured data points.
    """
    # constants in fig 1.
    RESISTOR=20
    INPUT_VOLTAGE = 2

    numerator=[1/(RESISTOR*capacitor), 0]
    denominator=[1, 1/(RESISTOR*capacitor), 1/(coil*capacitor)]
    transfer_function=sci.signal.TransferFunction(numerator, denominator)

    # calculated the output voltage at time points from the measured data.
    return INPUT_VOLTAGE*sci.signal.step(transfer_function, T=voltage_out["time"])[1]

voltage_out = get_measured_data("messwerte.npz")
voltage_out["predicted voltage"] = predict_voltage(COIL_NOMINAL, CAPACITOR_NOMINAL) # append dictionary with predicted values

# %% [markdown]
# # Analysis
# ## Plot Expected and Measured Data

# %%
def plot_ua():
    """
    Plot u_a in as a line graph and change the magnitude by 10*-3.
    """
    plt.plot(voltage_out["time"]*10**3, voltage_out["measured voltage"]*10**3, label="measured")
    plt.plot(voltage_out["time"]*10**3, voltage_out["predicted voltage"]*10**3, label='predicted')

    plt.title("Respone Voltage $U_a$ of the Bandfilter")
    plt.xlabel("Time in $ms$")
    plt.ylabel("$U_a$ in $mV$")
    plt.legend()

plot_ua()

# %% [markdown]
# ## Calculate Root Mean Square Error

# %%
def root_mean_square_error(predicted_voltage: list[float]) -> float: 
    """
    Calculate the root mean square error of the input list compared to the measured data of u_a.

    Input: Input Voltage as a list.
    Output: Root mean square error of the input voltage comparing input to measured data. Rounded to 2 decimal places.
    """
    rsme = np.sqrt(1/len(predicted_voltage) * np.sum(np.square(np.subtract(predicted_voltage, voltage_out["measured voltage"]))))
    return np.round(rsme, 2)

rsme_nominal = root_mean_square_error(voltage_out["predicted voltage"])
print(f"RSME with nominal values: {rsme_nominal*10**3} mV")
# Out:
# RSME with nominal values: 60.0 mV

# %% [markdown]
# # Find true Capacitor and Coil Values
#
# ## Create RSME Grid for Different Values

# %%
STEPS = 40
COIL_LOWER = 7e-3
COIL_UPPER = 12e-3
CAPACITOR_LOWER = 9 * 100e-6
CAPACITOR_UPPER = 16 * 100e-6

def create_rsme_grid(coil_list: list[float], capacitor_list : list[float]) -> np.ndarray:
    """
    Calculate the RSME for all pairs of capacitor and coil values. The voltage is calculated with the resistor values and compared to the measured data.

    Input: 1D list of capacitor values in F, 1d list of coil values in H.
    Output: A 2D matrix assigning a root mean square error for all positions x,y. x-axis is the coil values, y-axis is the capacitor values. 
    """
    # reserve array space
    rsme = np.zeros((len(coil_list), len(capacitor_list))) 

    # calculate rsme for all input pairs
    for i in range(len(coil_list)):
        for j in range(len(capacitor_list)):
            voltage = predict_voltage(coil_list[i], capacitor_list[j])
            rsme[i][j] = root_mean_square_error(voltage)

    return rsme

coil_range = np.linspace(COIL_LOWER, COIL_UPPER, STEPS).tolist()
capacitor_range = np.linspace(CAPACITOR_LOWER, CAPACITOR_UPPER, STEPS).tolist()

rsme_grid = create_rsme_grid(coil_range, capacitor_range)

# %% [markdown]
# ## Plot RSME Contour and Surface

# %%
def plot_rsme():
    """
    Plot RSME as 3D colormap and change the magnitude by 10**-3.
    """
    plt.contourf(coil_range*10**3, capacitor_range*10**3, rsme_grid*10**3, label="RSME")
    # plt.plot(coil_range, rsme_grid)

    plt.title('RMSE Contour Plot')
    plt.xlabel('Coil in $mH$')
    plt.ylabel('Capacitor in $mF$')
    # plt.colorbar(label='RMSE in $mV$')

plot_rsme()

def plot_rsme_3d():
    """
    Plot RSME as 3D height map and change the magnitude by 10**-3.
    """
    x,y = np.meshgrid(coil_range, capacitor_range)
    ax = plt.figure().add_subplot(projection='3d')
    ax.plot_surface(x*10**3, y*10**3, rsme_grid*10**3, cmap='viridis')
    plt.title('RMSE Surface Plot')
    ax.set_xlabel('Coil in $mH$')
    ax.set_ylabel('Capacitor in $mF$')
    ax.set_zlabel('RMSE in mV')

# plot_rsme_3d()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\janho\Coding\Python-Modellbildung-Simulation\exercise 7\tasks.ipynb Cell 12 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a>     plt.ylabel('Capacitor in $mF$')
#      <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a>     # plt.colorbar(label='RMSE in $mV$')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=12'>13</a> plot_rsme()
#      <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=14'>15</a> def plot_rsme_3d():
#      <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=15'>16</a>     """
#      <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=16'>17</a>     Plot RSME as 3D height map and change the magnitude by 10**-3.
#      <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=17'>18</a>     """
#
# c:\Users\janho\Coding\Python-Modellbildung-Simulation\exercise 7\tasks.ipynb Cell 12 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> def plot_rsme():
#       <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a>     """
#       <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>     Plot RSME as 3D colormap and change the magnitude by 10**-3.
#       <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a>     """
# ----> <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>     plt.contourf(coil_range*10**3, capacitor_range*10**3, rsme_grid*10**3, label="RSME")
#       <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a>     # plt.plot(coil_range, rsme_grid)
#       <a href='vscode-notebook-cell:/c%3A/Users/janho/Coding/Python-Modellbildung-Simulation/exercise%207/tasks.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a>     plt.title('RMSE Contour Plot')
#
# File c:\Users\janho\scoop\apps\python\current\Lib\site-packages\matplotlib\pyplot.py:2938, in contourf(data, *args, **kwargs)
#    2936 @_copy_docstring_and_deprecators(Axes.contourf)
#    2937 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2938     __ret = gca().contourf(
#    2939         *args, **({"data": data} if data is not None else {}), **kwargs
#    2940     )
#    2941     if __ret._A is not None:  # type: ignore[attr-defined]
#    2942         sci(__ret)
#
# File c:\Users\janho\scoop\apps\python\current\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\janho\scoop\apps\python\current\Lib\site-packages\matplotlib\axes\_axes.py:6528, in Axes.contourf(self, *args, **kwargs)
#    6519 """
#    6520 Plot filled contours.
#    6521
#    (...)
#    6525 %(contour_doc)s
#    6526 """
#    6527 kwargs['filled'] = True
# -> 6528 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6529 self._request_autoscale_view()
#    6530 return contours
#
# File c:\Users\janho\scoop\apps\python\current\Lib\site-packages\matplotlib\contour.py:847, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     843 if self.negative_linestyles is None:
#     844     self.negative_linestyles = \
#     845         mpl.rcParams['contour.negative_linestyle']
# --> 847 kwargs = self._process_args(*args, **kwargs)
#     848 self._process_levels()
#     850 self._extend_min = self.extend in ['min', 'both']
#
# File c:\Users\janho\scoop\apps\python\current\Lib\site-packages\matplotlib\contour.py:1533, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1530         corner_mask = mpl.rcParams['contour.corner_mask']
#    1531 self._corner_mask = corner_mask
# -> 1533 x, y, z = self._contour_args(args, kwargs)
#    1535 contour_generator = contourpy.contour_generator(
#    1536     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1537     line_type=contourpy.LineType.SeparateCode,
#    1538     fill_type=contourpy.FillType.OuterCode,
#    1539     chunk_size=self.nchunk)
#    1541 t = self.get_transform()
#
# File c:\Users\janho\scoop\apps\python\current\Lib\site-packages\matplotlib\contour.py:1573, in QuadContourSet._contour_args(self, args, kwargs)
#    1571 elif 2 < nargs <= 4:
#    1572     x, y, z_orig, *args = args
# -> 1573     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1575 else:
#    1576     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File c:\Users\janho\scoop\apps\python\current\Lib\site-packages\matplotlib\contour.py:1612, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1610 ny, = y.shape
#    1611 if nx != Nx:
# -> 1612     raise TypeError(f"Length of x ({nx}) must match number of "
#    1613                     f"columns in z ({Nx})")
#    1614 if ny != Ny:
#    1615     raise TypeError(f"Length of y ({ny}) must match number of "
#    1616                     f"rows in z ({Ny})")
#
# TypeError: Length of x (40000) must match number of columns in z (40)

# %% [markdown]
# ## Minimize rsme with variable parameters

# %%
def rsme_singel_input(params):
    # redefine rms function to work with a single input variable.
    # params is a 1d array. first element is the coil, second element is the capacitor.

    RESISTOR=20
    INPUT_VOLTAGE = 2

    numerator=[1/(RESISTOR*params[1]), 0]
    denominator=[1, 1/(RESISTOR*params[1]), 1/(params[0]*params[1])]
    transfer_function=sci.signal.TransferFunction(numerator, denominator)

    voltage =  INPUT_VOLTAGE*sci.signal.step(transfer_function, T=voltage_out["time"])[1]

    return root_mean_square_error(voltage)

def rsme_min():
    INITIAL_GUESS = [COIL_NOMINAL, CAPACITOR_NOMINAL]
    BOUNDS = [(COIL_LOWER, COIL_UPPER),(CAPACITOR_LOWER, CAPACITOR_UPPER)]

    # ! rsme function retuns discrete values. So minimize can't calculate a gradient. 
    return sci.optimize.dual_annealing(rsme_singel_input, BOUNDS, x0=INITIAL_GUESS)
    # return sci.optimize.minimize(rsme_singel_input, initial_guess, tol = 1e-15)

rsme_min = rsme_min()

best_coil, best_capacitor = np.round(rsme_min.x, 5)
this_rsme = np.round(rsme_min.fun,5)

print(f"True Coil:\t{best_coil*10**3} mH ")
print(f"True Capacitor:\t{best_capacitor*10**3} mF")
print(f"Minimum RMSE:\t{this_rsme*10**3} mV")
# Out:
# True Coil:	9.440000000000001 mH
# True Capacitor:	1.34 mF
# Minimum RMSE:	0.0 mV

# %% [markdown]
# # Find all possible parameters so that $RSME$ = 0
#
# ## Find Frequency of $U_{a,measured}$ with Fast Fourier Transformation

# %%
def find_frequency():
    fourier = np.fft.fft(voltage_out["measured"])
    dt = voltage_out["time"][1] - voltage_out["time"][0]
    n = voltage_out["time"].size
    frequency = np.fft.fftfreq(n, d=dt)

    id_max = np.argmax(np.abs(fourier))
    frequency_max = round(frequency[id_max], 2)
    print("Frequency of U_a measured: ", frequency_max, " Hz")

    plt.plot(np.fft.fftshift(frequency), np.fft.fftshift(abs(fourier)))
    plt.xlim(-75, 75)
    plt.xlabel("Frequency in Hz")
    plt.ylabel("Magnitude")
    plt.show()
    return frequency_max

frequency = find_frequency()
# Out:
# Frequency of U_a measured:  43.91  Hz

# %% [markdown]
# ## Model RSME for known optimal Capacitor and Coil Values

# %%
def capacitor_best(coil):
    capacitor = (7.71734*10**11)/(-76167098027154752 * coil + 641042574798611)
    return capacitor

capacitor_best = capacitor_best(coil_range)

rsme_var_coil = create_rsme_grid(coil_range, capacitor_best)

# plt.contourf(coil_list*10**3, capacitor_best*10**3, rsme_var_coil*10**3)
# plt.ylim(0.9, 1.6)
# plt.colorbar()

plt.plot(coil_range*10**3, capacitor_best*10**3)
# plt.ylim(0.9, 1.6)


# !!! Lösung für letzte Aufgabe: rsme ist minimal, wenn nullpunktdurchgänge identisch sind.
# !!! Ua muss gleiche Frequenz haben.
# !!! https://de.wikipedia.org/wiki/Thomsonsche_Schwingungsgleichung diese gleichung ist die antwort!!!!!!!!!!!

# %% [markdown]
# # Closing Notes
#
# The RSME function is minimal when the calculted voltage is (almost) identical to the measured voltage. The coordinates of the global minimum are the true hardware parameters of C and L.
#
# This is true of for all pairs of C and L that produce the same transferfunction
